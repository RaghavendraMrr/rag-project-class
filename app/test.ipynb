# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\__init__.py:47
#       1 """LangChain Google Gen AI integration.
#       2
#       3 !!! note "Vertex AI consolidation & compatibility"
#    (...)
#      36 more information on usage of this package.
#      37 """
#      39 from langchain_google_genai._enums import (
#      40     ComputerUse,
#      41     Environment,
#    (...)
#      45     Modality,
#      46 )
# ---> 47 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      48 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      49 from langchain_google_genai.llms import GoogleGenerativeAI
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:57
#      52 from google.genai.types import Tool as GoogleTool
#      53 from langchain_core.callbacks.manager import (
#      54     AsyncCallbackManagerForLLMRun,
#      55     CallbackManagerForLLMRun,
#      56 )
# ---> 57 from langchain_core.language_models import (
#      58     LangSmithParams,
#      59     LanguageModelInput,
#      60     ModelProfile,
#      61     ModelProfileRegistry,
#      62     is_openai_data_block,
#      63 )
#      64 from langchain_core.language_models.chat_models import BaseChatModel
#      65 from langchain_core.messages import (
#      66     AIMessage,
#      67     AIMessageChunk,
#    (...)
#      73     is_data_content_block,
#      74 )
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\__init__.py:110, in __getattr__(attr_name)
#     108 def __getattr__(attr_name: str) -> object:
#     109     module_name = _dynamic_imports.get(attr_name)
# --> 110     result = import_attr(attr_name, module_name, __spec__.parent)
#     111     globals()[attr_name] = result
#     112     return result
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\base.py:41
#      38     from langchain_core.outputs import LLMResult
#      40 try:
# ---> 41     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      43     _HAS_TRANSFORMERS = True
#      44 except ImportError:
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)
#      43     "feature_extractor_*.py",
#      44 ]
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\generic.py:51
#      47 logger = logging.get_logger(__name__)
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch
#      53     from ..model_debugging_utils import model_addition_debugger_context
#      56 # vendored from distutils.util
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
print("test")
# Out:
# test

# %%
# Load environment variables from .env file
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Verify OpenAI API key is set (for RAG examples later)
if os.getenv("GOOGLE_API_KEY"):
    print("GOOGLE_API_KEY key is configured")
else:
    print("Warning: OpenAI API key not found. Some RAG examples will not work.")
    print("Create a .env file with: OPENAI_API_KEY=your-key-here")
    
api_key=os.getenv("GOOGLE_API_KEY")
# Out:
# GOOGLE_API_KEY key is configured

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    api_key=os.getenv("GOOGLE_API_KEY")
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2 llm=ChatGoogleGenerativeAI(
#       3     model="gemini-2.5-flash",
#       4     temperature=0,
#       5     api_key=os.getenv("GOOGLE_API_KEY")
#       6 )
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\__init__.py:47
#       1 """LangChain Google Gen AI integration.
#       2
#       3 !!! note "Vertex AI consolidation & compatibility"
#    (...)
#      36 more information on usage of this package.
#      37 """
#      39 from langchain_google_genai._enums import (
#      40     ComputerUse,
#      41     Environment,
#    (...)
#      45     Modality,
#      46 )
# ---> 47 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      48 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      49 from langchain_google_genai.llms import GoogleGenerativeAI
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:57
#      52 from google.genai.types import Tool as GoogleTool
#      53 from langchain_core.callbacks.manager import (
#      54     AsyncCallbackManagerForLLMRun,
#      55     CallbackManagerForLLMRun,
#      56 )
# ---> 57 from langchain_core.language_models import (
#      58     LangSmithParams,
#      59     LanguageModelInput,
#      60     ModelProfile,
#      61     ModelProfileRegistry,
#      62     is_openai_data_block,
#      63 )
#      64 from langchain_core.language_models.chat_models import BaseChatModel
#      65 from langchain_core.messages import (
#      66     AIMessage,
#      67     AIMessageChunk,
#    (...)
#      73     is_data_content_block,
#      74 )
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\__init__.py:110, in __getattr__(attr_name)
#     108 def __getattr__(attr_name: str) -> object:
#     109     module_name = _dynamic_imports.get(attr_name)
# --> 110     result = import_attr(attr_name, module_name, __spec__.parent)
#     111     globals()[attr_name] = result
#     112     return result
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\base.py:41
#      38     from langchain_core.outputs import LLMResult
#      40 try:
# ---> 41     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      43     _HAS_TRANSFORMERS = True
#      44 except ImportError:
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)
#      43     "feature_extractor_*.py",
#      44 ]
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\generic.py:51
#      47 logger = logging.get_logger(__name__)
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch
#      53     from ..model_debugging_utils import model_addition_debugger_context
#      56 # vendored from distutils.util
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\z0030avf\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.
